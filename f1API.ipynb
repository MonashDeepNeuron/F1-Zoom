# %%
# %pip install fastf1
# Out:
# Collecting fastf1
#   Obtaining dependency information for fastf1 from https://files.pythonhosted.org/packages/22/7d/4681074549e8d4d7b473ae72a6ade18e453b86ddcb496cff2e98fcfd421b/fastf1-3.6.1-py3-none-any.whl.metadata
#   Downloading fastf1-3.6.1-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: matplotlib<4.0.0,>=3.5.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from fastf1) (3.10.0)
# Requirement already satisfied: numpy<3.0.0,>=1.23.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from fastf1) (1.26.3)
# Requirement already satisfied: pandas<3.0.0,>=1.4.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from fastf1) (2.2.3)
# Requirement already satisfied: python-dateutil in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from fastf1) (2.8.2)
# Collecting rapidfuzz (from fastf1)
#   Obtaining dependency information for rapidfuzz from https://files.pythonhosted.org/packages/c0/f3/67f5c5cd4d728993c48c1dcb5da54338d77c03c34b4903cc7839a3b89faf/rapidfuzz-3.14.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading rapidfuzz-3.14.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (12 kB)
# Collecting requests-cache>=1.0.0 (from fastf1)
#   Obtaining dependency information for requests-cache>=1.0.0 from https://files.pythonhosted.org/packages/4e/2e/8f4051119f460cfc786aa91f212165bb6e643283b533db572d7b33952bd2/requests_cache-1.2.1-py3-none-any.whl.metadata
#   Downloading requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: requests>=2.28.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from fastf1) (2.31.0)
# Requirement already satisfied: scipy<2.0.0,>=1.8.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from fastf1) (1.11.1)
# Collecting timple>=0.1.6 (from fastf1)
#   Obtaining dependency information for timple>=0.1.6 from https://files.pythonhosted.org/packages/75/45/c73f9af9a9d50b0ae972d185ef2255c62524d1aa20a76531dd2fcda48819/timple-0.1.8-py3-none-any.whl.metadata
#   Downloading timple-0.1.8-py3-none-any.whl.metadata (2.0 kB)
# Collecting websockets<14,>=10.3 (from fastf1)
#   Obtaining dependency information for websockets<14,>=10.3 from https://files.pythonhosted.org/packages/68/d4/c8c7c1e5b40ee03c5cc235955b0fb1ec90e7e37685a5f69229ad4708dcde/websockets-13.1-cp311-cp311-macosx_11_0_arm64.whl.metadata
#   Downloading websockets-13.1-cp311-cp311-macosx_11_0_arm64.whl.metadata (6.8 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (23.1)
# Requirement already satisfied: pillow>=8 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (10.0.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from matplotlib<4.0.0,>=3.5.1->fastf1) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=1.4.1->fastf1) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from pandas<3.0.0,>=1.4.1->fastf1) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from python-dateutil->fastf1) (1.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->fastf1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->fastf1) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->fastf1) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from requests>=2.28.1->fastf1) (2025.7.14)
# Requirement already satisfied: attrs>=21.2 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from requests-cache>=1.0.0->fastf1) (23.2.0)
# Collecting cattrs>=22.2 (from requests-cache>=1.0.0->fastf1)
#   Obtaining dependency information for cattrs>=22.2 from https://files.pythonhosted.org/packages/d8/2b/a40e1488fdfa02d3f9a653a61a5935ea08b3c2225ee818db6a76c7ba9695/cattrs-25.3.0-py3-none-any.whl.metadata
#   Downloading cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in /Users/amarpritsingh/anaconda3/lib/python3.11/site-packages (from requests-cache>=1.0.0->fastf1) (3.10.0)
# Collecting url-normalize>=1.4 (from requests-cache>=1.0.0->fastf1)
#   Obtaining dependency information for url-normalize>=1.4 from https://files.pythonhosted.org/packages/bc/d9/5ec15501b675f7bc07c5d16aa70d8d778b12375686b6efd47656efdc67cd/url_normalize-2.2.1-py3-none-any.whl.metadata
#   Downloading url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting attrs>=21.2 (from requests-cache>=1.0.0->fastf1)
#   Obtaining dependency information for attrs>=21.2 from https://files.pythonhosted.org/packages/3a/2a/7cc015f5b9f5db42b7d48157e23356022889fc354a2813c15934b7cb5c0e/attrs-25.4.0-py3-none-any.whl.metadata
#   Downloading attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting typing-extensions>=4.14.0 (from cattrs>=22.2->requests-cache>=1.0.0->fastf1)
#   Obtaining dependency information for typing-extensions>=4.14.0 from https://files.pythonhosted.org/packages/18/67/36e9267722cc04a6b9f15c7f3441c2363321a3ea07da7ae0c0707beb2a9c/typing_extensions-4.15.0-py3-none-any.whl.metadata
#   Downloading typing_extensions-4.15.0-py3-none-any.whl.metadata (3.3 kB)
# Downloading fastf1-3.6.1-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 148.6/148.6 kB 569.3 kB/s eta 0:00:000:00:01
# Downloading requests_cache-1.2.1-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.4/61.4 kB 3.1 MB/s eta 0:00:00
# Downloading timple-0.1.8-py3-none-any.whl (17 kB)
# Downloading websockets-13.1-cp311-cp311-macosx_11_0_arm64.whl (155 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.7/155.7 kB 9.3 MB/s eta 0:00:00
# Downloading rapidfuzz-3.14.1-cp311-cp311-macosx_11_0_arm64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 14.5 MB/s eta 0:00:00a 0:00:01
# Downloading cattrs-25.3.0-py3-none-any.whl (70 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.7/70.7 kB 12.0 MB/s eta 0:00:00
# Downloading attrs-25.4.0-py3-none-any.whl (67 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.6/67.6 kB 10.6 MB/s eta 0:00:00
# Downloading url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Downloading typing_extensions-4.15.0-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.6/44.6 kB 6.0 MB/s eta 0:00:00
# Installing collected packages: websockets, url-normalize, typing-extensions, rapidfuzz, attrs, cattrs, timple, requests-cache, fastf1
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.9.0
#     Uninstalling typing_extensions-4.9.0:
#       Successfully uninstalled typing_extensions-4.9.0
#   Attempting uninstall: attrs
#     Found existing installation: attrs 23.2.0
#     Uninstalling attrs-23.2.0:
#       Successfully uninstalled attrs-23.2.0
# Successfully installed attrs-25.4.0 cattrs-25.3.0 fastf1-3.6.1 rapidfuzz-3.14.1 requests-cache-1.2.1 timple-0.1.8 typing-extensions-4.15.0 url-normalize-2.2.1 websockets-13.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import fastf1
from fastf1 import plotting
import matplotlib.pyplot as plt
from datetime import datetime
from zoneinfo import ZoneInfo
import matplotlib

aest_tz = ZoneInfo("Australia/Melbourne")

yearsToCollect = [2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022, 2023, 2024]

# %%
import logging

logging.getLogger("fastf1").setLevel(logging.CRITICAL)

# %% [markdown]
# Get the event

# %%
calendar_2025 = fastf1.get_events_remaining(
    dt=datetime.now(),
    include_testing=True,
    backend='ergast'
)

allNextRaceData = calendar_2025.iloc[0]

nextRace = calendar_2025.iloc[0][['EventName', 'EventDate', 'Location']]

calendar_2025['EventDate'] = (
    calendar_2025['EventDate']
    .dt.tz_localize('UTC')
    .dt.tz_convert('Australia/Sydney')
)


print(f"\nNext Race: {nextRace['EventName']} in {nextRace['Location']} at {nextRace['EventDate']}")
# print(allNextRaceData)
# Out:
# RoundNumber                                19
# Country                                   USA
# Location                               Austin
# OfficialEventName
# EventDate                 2025-10-19 19:00:00
# EventName            United States Grand Prix
# EventFormat                 sprint_qualifying
# Session1                           Practice 1
# Session1Date                             None
# Session1DateUtc           2025-10-17 00:00:00
# Session2                    Sprint Qualifying
# Session2Date                             None
# Session2DateUtc           2025-10-17 00:00:00
# Session3                               Sprint
# Session3Date                             None
# Session3DateUtc           2025-10-18 00:00:00
# Session4                           Qualifying
# Session4Date                             None
# Session4DateUtc           2025-10-18 00:00:00
# Session5                                 Race
# Session5Date                             None
# Session5DateUtc           2025-10-19 19:00:00
# F1ApiSupport                             True
# Name: 18, dtype: object

# %% [markdown]
# Average lap time over past n years

# %%
eventName = nextRace['EventName']
eventDate = nextRace['EventDate']
eventLocation = nextRace['Location']

fastestLapData = []
averageLapData = []

for year in yearsToCollect:
    try:
        print(f"processing {year} {eventName}")
        session = fastf1.get_session(year, nextRace['EventName'], 'R')
        
        session.load()
        
        laps = session.laps
        fastest_lap = laps.pick_fastest()
        fastest_lap_driver = fastest_lap['Driver']
        fastest_lap_time = fastest_lap['LapTime'].total_seconds() * 1000
        fastest_lap_number = fastest_lap['LapNumber']
        
        average_lap_time = laps.LapTime.mean().total_seconds() * 1000
        
        averageLapData.append((year, average_lap_time))
        fastestLapData.append((year, fastest_lap_driver, fastest_lap_time, fastest_lap_number))
        
        # print(f"{year} Fastest Lap: {fastest_lap_time} by {fastest_lap_driver} on lap {fastest_lap_number}")
    
    except Exception as e:
        print(f"Could not process {year} {eventName}: {e}")
        print("-----" * 10)
        continue
    

print("-----" * 20)
for data in fastestLapData:
    year, driver, lap_time, lap_number = data
    print(f"{year} Fastest Lap: {lap_time} by {driver} on lap {lap_number}")
    print("-----" * 20)


for data in averageLapData:
    year, avg_lap_time = data
    print(f"{year} Average Lap Time: {avg_lap_time}")
    print("-----" * 20)
# Out:
# processing 2014 United States Grand Prix
# Could not process 2014 United States Grand Prix: The data you are trying to access has not been loaded yet. See `Session.load`
# --------------------------------------------------
# processing 2015 United States Grand Prix
# Could not process 2015 United States Grand Prix: The data you are trying to access has not been loaded yet. See `Session.load`
# --------------------------------------------------
# processing 2016 United States Grand Prix
# Could not process 2016 United States Grand Prix: The data you are trying to access has not been loaded yet. See `Session.load`
# --------------------------------------------------
# processing 2017 United States Grand Prix
# Could not process 2017 United States Grand Prix: The data you are trying to access has not been loaded yet. See `Session.load`
# --------------------------------------------------
# processing 2018 United States Grand Prix
# processing 2019 United States Grand Prix
# processing 2020 United States Grand Prix
# processing 2021 United States Grand Prix
# processing 2022 United States Grand Prix
# processing 2023 United States Grand Prix
# processing 2024 United States Grand Prix
# ----------------------------------------------------------------------------------------------------
# 2018 Fastest Lap: 97392.0 by HAM on lap 40.0
# ----------------------------------------------------------------------------------------------------
# 2019 Fastest Lap: 96169.0 by LEC on lap 44.0
# ----------------------------------------------------------------------------------------------------
# 2020 Fastest Lap: 76627.0 by HAM on lap 70.0
# ----------------------------------------------------------------------------------------------------
# 2021 Fastest Lap: 98485.0 by HAM on lap 41.0
# ----------------------------------------------------------------------------------------------------
# 2022 Fastest Lap: 98788.0 by RUS on lap 56.0
# ----------------------------------------------------------------------------------------------------
# 2023 Fastest Lap: 98139.0 by TSU on lap 56.0
# ----------------------------------------------------------------------------------------------------
# 2024 Fastest Lap: 97330.0 by OCO on lap 53.0
# ----------------------------------------------------------------------------------------------------
# 2018 Average Lap Time: 102939.246
# ----------------------------------------------------------------------------------------------------
# 2019 Average Lap Time: 102680.347
# ----------------------------------------------------------------------------------------------------
# 2020 Average Lap Time: 84120.208
# ----------------------------------------------------------------------------------------------------
# 2021 Average Lap Time: 103737.56400000001
# ----------------------------------------------------------------------------------------------------
# 2022 Average Lap Time: 106261.205
# ----------------------------------------------------------------------------------------------------
# 2023 Average Lap Time: 103249.899
# ----------------------------------------------------------------------------------------------------
# 2024 Average Lap Time: 101956.361
# ----------------------------------------------------------------------------------------------------

# %%
years = [data[0] for data in fastestLapData]
# Convert milliseconds to seconds
fastest_times = [data[2]/1000 for data in fastestLapData]
avg_times = [data[1]/1000 for data in averageLapData]

plt.figure(figsize=(12, 6))
plt.plot(years, fastest_times, 'o-', color='red', label='Fastest Lap Times')
plt.plot(years, avg_times, 'o-', color='blue', label='Average Lap Times')

# Add labels for fastest lap times
for x, y in zip(years, fastest_times):
    plt.annotate(f'{y:.3f}s', 
                (x, y),
                textcoords="offset points",
                xytext=(0,10),
                ha='center',
                color='red',
                fontsize=8)

# Add labels for average lap times
for x, y in zip(years, avg_times):
    plt.annotate(f'{y:.3f}s', 
                (x, y),
                textcoords="offset points",
                xytext=(0,-15),
                ha='center',
                color='blue',
                fontsize=8)

plt.title(f'Lap Times Evolution: {eventName} ({eventLocation})')
plt.xlabel('Year')
plt.ylabel('Lap Time (seconds)')
plt.grid(True, linestyle='--', alpha=0.7)
plt.legend()

# Rotate x-axis labels for better readability
plt.xticks(years, rotation=45)

# Add some padding to prevent label cutoff
plt.tight_layout()

plt.show()

# %% [markdown]
# To calculate the time lost on an in-lap and out-lap we can compare (DURING GREEN FLAG)
#
# average_in_lap = average(average lap time - average in-lap)
#
# average_out_lap = average(average lap time - average out-lap)

# %%
import numpy as np

in_lap_differences = []
out_lap_differences = []

for year in yearsToCollect:
    try:
        print(f"Processing pit lap analysis for {year} {eventName}")
        # load only laps (faster, avoids telemetry downloads)
        session = fastf1.get_session(year, eventName, 'R')
        session.load(laps=True)

        laps = session.laps
        if laps is None or laps.empty:
            print(f"  No laps for {year}; skipping.")
            continue

        # get pit-related laps (may raise if not available for season)
        try:
            pit_both = laps.pick_box_laps('both')
            in_laps = laps.pick_box_laps('in')
            out_laps = laps.pick_box_laps('out')
        except Exception as e:
            print(f"  Pit data not available for {year}: {e}")
            continue

        # drop laps where they come out of pits and pit again (rare)
        racing_laps = laps.drop(pit_both.index, errors='ignore')

        def mean_secs(df):
            if df is None or df.empty:
                return np.nan
            return df['LapTime'].dropna().dt.total_seconds().mean()

        avg_normal = mean_secs(racing_laps)
        avg_in = mean_secs(in_laps)
        avg_out = mean_secs(out_laps)

        if not np.isnan(avg_in) and not np.isnan(avg_normal):
            in_lap_differences.append(avg_in - avg_normal)
        if not np.isnan(avg_out) and not np.isnan(avg_normal):
            out_lap_differences.append(avg_out - avg_normal)

    except Exception as e:
        print(f"  Could not process {year}: {e}")
        continue

avg_in_lap_loss = sum(in_lap_differences) / len(in_lap_differences) if in_lap_differences else float('nan')
avg_out_lap_loss = sum(out_lap_differences) / len(out_lap_differences) if out_lap_differences else float('nan')

print(f"Average in-lap loss:  {round(avg_in_lap_loss, 3)}")
print(f"Average out-lap loss: {round(avg_out_lap_loss, 3)}")
if not np.isnan(avg_in_lap_loss) and not np.isnan(avg_out_lap_loss):
    print(f"Total average pit loss: {round(avg_in_lap_loss + avg_out_lap_loss, 3)}")
# Out:
# Processing pit lap analysis for 2014 United States Grand Prix
#   Could not process 2014: The data you are trying to access has not been loaded yet. See `Session.load`
# Processing pit lap analysis for 2015 United States Grand Prix
#   Could not process 2015: The data you are trying to access has not been loaded yet. See `Session.load`
# Processing pit lap analysis for 2016 United States Grand Prix
#   Could not process 2016: The data you are trying to access has not been loaded yet. See `Session.load`
# Processing pit lap analysis for 2017 United States Grand Prix
#   Could not process 2017: The data you are trying to access has not been loaded yet. See `Session.load`
# Processing pit lap analysis for 2018 United States Grand Prix
# Processing pit lap analysis for 2019 United States Grand Prix
# Processing pit lap analysis for 2020 United States Grand Prix
# Processing pit lap analysis for 2021 United States Grand Prix
# Processing pit lap analysis for 2022 United States Grand Prix
# Processing pit lap analysis for 2023 United States Grand Prix
# Processing pit lap analysis for 2024 United States Grand Prix
#
# === Average Time Lost vs Racing-Lap Average ===
# Average in-lap loss:  4.484
# Average out-lap loss: 20.856
# Total average pit loss: 25.34

# %% [markdown]
# to model car
#
# We have to measure how the tyres increasing in age impact the lap time
#
# to cater for traffic we have to ensure that the car we are collecting data on is not within 10 seconds of the car in front at any point in time.

# %% [markdown]
# To measure the impact of a lap on tyres, we will use Q3 (qualifying) to measure the impact of a racing lap on the tyres.
#
# Top-end / flow = how quickly the lap is covered (long straights, high average speed, lower sustained slip)
#
# corner / traction severity = how much time is spent cornering / braking / accelerating, lateral / longitude energy into the rubber
